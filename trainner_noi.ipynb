# %%
import pandas as pd
from sklearn.svm import LinearSVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
import seaborn as sns


from src.preprocessing import Preprocessing
from src.visualization import Visualization
from src.experiments import Experiments

# %%
train = pd.read_csv('data/train_noi.csv', sep = '\t')
column_target = 'hor_noi'

Preprocessing.data_info(train)
# #Analisando a regressão de cada feature separadamente...
# Visualization.correlation_features(train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         143 non-null    int64
#  1   distancia          143 non-null    int64
#  2   populacao          143 non-null    int64
#  3   pib                143 non-null    int64
#  4   renda              143 non-null    float64
#  5   idhm               143 non-null    float64
#  6   urbano             143 non-null    float64
#  7   envelhecimento     143 non-null    float64
#  8   esp_vida           143 non-null    float64
#  9   dependencia        143 non-null    float64
#  10  freq_superior      143 non-null    float64
#  11  sup_completo       143 non-null    float64
#  12  pop15_24           143 non-null    float64
#  13  pop25_34           143 non-null    float64
#  14  pop35_44           143 non-null    float64
#  15  pop45_54           143 non-null    float64
#  16  pop55_64           143 non-null    float64
#  17  mulheres           141 non-null    float64
#  18  desigualdade       143 non-null    float64
#  19  autonomos          143 non-null    float64
#  20  empregadores       143 non-null    float64
#  21  agropecuaria       143 non-null    float64
#  22  comercio           143 non-null    float64
#  23  construcao         143 non-null    float64
#  24  ext_mineral        143 non-null    float64
#  25  servicos           143 non-null    float64
#  26  siup               143 non-null    float64
#  27  ind_transformacao  143 non-null    float64
#  28  func_publicos      143 non-null    float64
#  29  hor_noi            143 non-null    int64
# dtypes: float64(25), int64(5)
# memory usage: 33.6 KB
# {'shape': (143, 30),
#  'describe':        Unnamed: 0    distancia     populacao           pib        renda  \
#  count   143.00000   143.000000  1.430000e+02  1.430000e+02   143.000000
#  mean     71.00000   448.839161  5.988950e+06  3.152888e+08  1235.852168
#  std      41.42463   239.283044  5.165966e+06  3.062804e+08   204.282761
#  min       0.00000    88.000000  4.384540e+05  1.604788e+07   723.320000
#  25%      35.50000   259.500000  1.632562e+06  6.730295e+07  1095.350000
#  50%      71.00000   428.000000  3.080943e+06  1.072350e+08  1230.110000
#  75%     106.50000   578.000000  1.231006e+07  7.012290e+08  1348.860000
#  max     142.00000  1464.000000  1.897093e+07  1.036883e+09  1778.200000
#
#               idhm      urbano  envelhecimento    esp_vida  dependencia  ...  \
#  count  143.000000  143.000000      143.000000  143.000000   143.000000  ...
#  mean     0.891469   93.668601        8.059371   76.201958    40.279720  ...
#  std      0.850592    4.256755        1.193415    0.784592     1.953199  ...
#  min      0.740000   73.240000        4.350000   74.030000    34.810000  ...
#  25%      0.780000   91.900000        7.365000   75.770000    38.880000  ...
#  50%      0.790000   95.090000        8.250000   76.220000    40.250000  ...
#  75%      0.810000   96.375000        8.840000   76.775000    41.325000  ...
#  max      8.300000   98.340000       12.260000   78.390000    47.680000  ...
#
#         empregadores  agropecuaria    comercio  construcao  ext_mineral  \
#  count    143.000000    143.000000  143.000000  143.000000   143.000000
#  mean       2.963357      3.406853   17.023287    7.043986     0.384056
#  std        0.630613      3.749333    1.497273    0.960472     0.485946
#  min        1.030000      0.320000   12.240000    5.080000     0.030000
#  25%        2.520000      0.990000   16.170000    6.350000     0.090000
#  50%        2.830000      2.460000   16.770000    6.970000     0.220000
#  75%        3.380000      4.210000   17.995000    7.685000     0.450000
#  max        4.410000     26.140000   22.210000   10.260000     3.490000
#
#           servicos        siup  ind_transformacao  func_publicos     hor_noi
#  count  143.000000  143.000000         143.000000     143.000000  143.000000
#  mean    52.704615    1.013636          11.490909       5.900629    2.958042
#  std      4.453250    0.250516           3.529247       2.037146    3.048607
#  min     37.570000    0.600000           3.990000       2.230000    0.000000
#  25%     50.260000    0.865000           9.140000       4.460000    1.000000
#  50%     52.840000    0.990000          11.270000       5.580000    2.000000
#  75%     55.075000    1.095000          13.050000       7.365000    4.500000
#  max     64.860000    2.440000          23.410000      11.890000   18.000000
#
#  [8 rows x 30 columns],
#  'info': None,
#  'types': Unnamed: 0             int64
#  distancia              int64
#  populacao              int64
#  pib                    int64
#  renda                float64
#  idhm                 float64
#  urbano               float64
#  envelhecimento       float64
#  esp_vida             float64
#  dependencia          float64
#  freq_superior        float64
#  sup_completo         float64
#  pop15_24             float64
#  pop25_34             float64
#  pop35_44             float64
#  pop45_54             float64
#  pop55_64             float64
#  mulheres             float64
#  desigualdade         float64
#  autonomos            float64
#  empregadores         float64
#  agropecuaria         float64
#  comercio             float64
#  construcao           float64
#  ext_mineral          float64
#  servicos             float64
#  siup                 float64
#  ind_transformacao    float64
#  func_publicos        float64
#  hor_noi                int64
#  dtype: object}

# %%
train.fillna(0, inplace = True)
delete_columns = ['Unnamed: 0']

train.drop(delete_columns, axis=1, inplace=True)

# %%
df_train = Preprocessing.select_features(train, column_target)
Visualization.correlation_features(df_train)

# %%
ax = sns.boxplot(data=df_train, orient="h", palette="Set2")

# %%
target = df_train[column_target]
df_train.drop(column_target, axis = 1, inplace = True)

x_train, x_test, y_train, y_test = train_test_split(df_train, target, test_size=0.2, random_state=25)
experiments = Experiments(x_train, y_train, x_test, y_test)

# %%
linear_SVR, linear_SVR_measurement  = experiments.models_correlations(LinearSVR())
linear_SVR_measurement
# Out:
# {'model': LinearSVR(),
#  'train_time': 0.0066759586334228516,
#  'test_time': 0.00199127197265625,
#  'score': -1.3513513513513513,
#  'explained_variance_score': 0.0,
#  'max_error': 10.0,
#  'mean_absolute_error': 3.45,
#  'mean_squared_error': 20.69,
#  'r2_score': -1.35}

# %%
decision_tree_regressor, decision_tree_regressor_measurement = experiments.models_correlations(DecisionTreeRegressor())
decision_tree_regressor_measurement
# Out:
# {'model': DecisionTreeRegressor(),
#  'train_time': 0.0035772323608398438,
#  'test_time': 0.0021011829376220703,
#  'score': -0.3206756756756757,
#  'explained_variance_score': -0.29,
#  'max_error': 7.0,
#  'mean_absolute_error': 2.66,
#  'mean_squared_error': 11.62,
#  'r2_score': -0.32}

# %%
k_neighbors_regressor, k_neighbors_regressor_measurement = experiments.models_correlations(KNeighborsRegressor())
k_neighbors_regressor_measurement
# Out:
# {'model': KNeighborsRegressor(),
#  'train_time': 0.002713441848754883,
#  'test_time': 0.002086162567138672,
#  'score': 0.182983783783784,
#  'explained_variance_score': 0.28,
#  'max_error': 6.4,
#  'mean_absolute_error': 2.14,
#  'mean_squared_error': 7.19,
#  'r2_score': 0.18}

# %%
random_forest_regressor, random_forest_regressor_measurement = experiments.models_correlations(RandomForestRegressor())
random_forest_regressor_measurement
# Out:
# {'model': RandomForestRegressor(),
#  'train_time': 0.1370408535003662,
#  'test_time': 0.0066814422607421875,
#  'score': 0.3931013243243243,
#  'explained_variance_score': 0.41,
#  'max_error': 5.04,
#  'mean_absolute_error': 1.87,
#  'mean_squared_error': 5.34,
#  'r2_score': 0.39}

# %%
mlp_regressor, mlp_regressor_measurement = experiments.models_correlations(MLPRegressor())
mlp_regressor_measurement
# Out:
# {'model': MLPRegressor(),
#  'train_time': 0.09708571434020996,
#  'test_time': 0.002643108367919922,
#  'score': -22059434201693.938,
#  'explained_variance_score': -10040692995458.79,
#  'max_error': 22659519.87,
#  'mean_absolute_error': 10283651.58,
#  'mean_squared_error': 194102036970918.6,
#  'r2_score': -22059434201693.94}
